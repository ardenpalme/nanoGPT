# %%
import torch

# Check if XPU is available
if torch.xpu.is_available():
    device = torch.device("xpu")
    print(f"XPU is available. Using {torch.xpu.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("XPU not available, using CPU.")

# Create a tensor and move it to the selected device
tensor = torch.randn(3, 3).to(device)
print(f"Tensor is on: {tensor.device}")
# Out:
# XPU is available. Using Intel(R) Arc(TM) Graphics
# Tensor is on: xpu:0
